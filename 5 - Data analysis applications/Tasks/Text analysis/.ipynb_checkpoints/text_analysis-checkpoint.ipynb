# %% [markdown]
# # Классификация текстов: спам-фильтр для SMS.
# В этом задании вам предстоит взять открытый датасет с SMS-сообщениями, размеченными на спам ("spam") и не спам ("ham"), построить на нем классификатор текстов на эти два класса, оценить его качество с помощью кросс-валидации, протестировать его работу на отдельных примерах, и посмотреть, что будет происходить с качеством, если менять параметры вашей модели.

# %%
import pandas as pd
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import cross_val_score
from sklearn.pipeline import Pipeline
from sklearn.naive_bayes import MultinomialNB

# %% [markdown]
# ## Задание 1.
# Загрузите датасет. Описание датасета можно посмотреть http://www.dt.fee.unicamp.br/~tiago/smsspamcollection/ .
# Считайте датасет в Python (можете сразу грузить все в память, выборка небольшая), выясните, что используется в качестве разделителей и как проставляются метки классов.

# %%
with open('smsspamcollection/SMSSpamCollection.txt', 'r') as f:
    sms_data = f.read().splitlines()

sms_data[:5]
# Out:
# ['ham\tGo until jurong point, crazy.. Available only in bugis n great world la e buffet... Cine there got amore wat...',
#  'ham\tOk lar... Joking wif u oni...',
#  "spam\tFree entry in 2 a wkly comp to win FA Cup final tkts 21st May 2005. Text FA to 87121 to receive entry question(std txt rate)T&C's apply 08452810075over18's",
#  'ham\tU dun say so early hor... U c already then say...',
#  "ham\tNah I don't think he goes to usf, he lives around here though"]

# %% [markdown]
# ## Задание 2.
# Подготовьте для дальнейшей работы два списка: список текстов в порядке их следования в датасете и список соответствующих им меток классов. В качестве метки класса используйте 1 для спама и 0 для "не спама".

# %%
texts = [line.split('\t')[1] for line in sms_data]
labels = [line.split('\t')[0] for line in sms_data]
blabels = [1 if x == 'spam' else 0 for x in labels]

# %% [markdown]
# ## Задание 3.
# Используя sklearn.feature_extraction.text.CountVectorizer со стандартными настройками, получите из списка текстов матрицу признаков X.

# %%
v = CountVectorizer()
mx = v.fit_transform(texts)
v.get_feature_names()
# Out:
# ['00',
#  '000',
#  '000pes',
#  '008704050406',
#  '0089',
#  '0121',
#  '01223585236',
#  '01223585334',
#  '0125698789',
#  '02',
#  '0207',
#  '02072069400',
#  '02073162414',
#  '02085076972',
#  '021',
#  '03',
#  '04',
#  '0430',
#  '05',
#  '050703',
#  '0578',
#  '06',
#  '07',
#  '07008009200',
#  '07046744435',
#  '07090201529',
#  '07090298926',
#  '07099833605',
#  '07123456789',
#  '0721072',
#  '07732584351',
#  '07734396839',
#  '07742676969',
#  '07753741225',
#  '0776xxxxxxx',
#  '07781482378',
#  '07786200117',
#  '077xxx',
#  '078',
#  '07801543489',
#  '07808',
#  '07808247860',
#  '07808726822',
#  '07815296484',
#  '07821230901',
#  '078498',
#  '07880867867',
#  '0789xxxxxxx',
#  '07946746291',
#  '0796xxxxxx',
#  '07973788240',
#  '07xxxxxxxxx',
#  '08',
#  '0800',
#  '08000407165',
#  '08000776320',
#  '08000839402',
#  '08000930705',
#  '08000938767',
#  '08001950382',
#  '08002888812',
#  '08002986030',
#  '08002986906',
#  '08002988890',
# ...

# %% [markdown]
# ## Задание 4.
# Оцените качество классификации текстов с помощью LogisticRegression() с параметрами по умолчанию, используя sklearn.model_selection.cross_val_score и посчитав среднее арифметическое качества на отдельных fold'ах. Установите random_state=2. Параметр cv задайте равным 10. В качестве метрики качества используйте f1-меру. Получившееся качество - один из ответов, которые потребуются при сдаче задания. Ответ округлить до 1 знака после запятой.

# %%
steps = [('CountVectorizer', CountVectorizer()), 
         ('LogisticRegression', LogisticRegression(random_state=2))]

pipe = Pipeline(steps)

score = cross_val_score(pipe, texts, blabels, cv=10, scoring='f1').mean()
print('Mean value of F1 score: ' + str(score))

with open('answer1.txt', 'w') as f:
    f.write(str(round(score, 1)))
# Out:
# Mean value of F1 score: 0.9311052112181922

# %% [markdown]
# ## Задание 5.
# А теперь обучите классификатор на всей выборке и спрогнозируйте с его помощью класс для следующих сообщений:
#
# "FreeMsg: Txt: CALL to No: 86888 & claim your reward of 3 hours talk time to use from your phone now! Subscribe6GB"
#
# "FreeMsg: Txt: claim your reward of 3 hours talk time"
#
# "Have you visited the last lecture on physics?"
#
# "Have you visited the last lecture on physics? Just buy this book and you will have all materials! Only 99$"
#
# "Only 99$"

# %%
test_texts = ['FreeMsg: Txt: CALL to No: 86888 & claim your reward of 3 hours talk time to use from your phone now! Subscribe6GB',
              'FreeMsg: Txt: claim your reward of 3 hours talk time',
              'Have you visited the last lecture on physics?',
              'Have you visited the last lecture on physics? Just buy this book and you will have all materials! Only 99$',
              'Only 99$']

pipe.fit(texts, blabels)
predict1 = pipe.predict(test_texts)
print('Predictions for test texts: ' + ', '.join(map(str, predict1)))

with open('answer2.txt', 'w') as f:
    f.write(' '.join(map(str, predict1)))
# Out:
# Predictions for test texts: 1, 1, 0, 0, 0

# %% [markdown]
# ## Задание 6.
# Задайте в CountVectorizer параметр ngram_range=(2,2), затем ngram_range=(3,3), затем ngram_range=(1,3). Во всех трех случаях измерьте получившееся в кросс-валидации значение f1-меры, округлите до второго знака после точки, и выпишете результаты через пробел в том же порядке. В данном эксперименте мы пробовали добавлять в признаки n-граммы для разных диапазонов n - только биграммы, только триграммы, и, наконец, все вместе - униграммы, биграммы и триграммы. Обратите внимание, что статистики по биграммам и триграммам намного меньше, поэтому классификатор только на них работает хуже. В то же время это не ухудшает результат сколько-нибудь существенно, если добавлять их вместе с униграммами, т.к. за счет регуляризации линейный классификатор не склонен сильно переобучаться на этих признаках.

# %%
ngram_range = [(2,2), (3, 3), (1, 3)]
scores1 = []

for nr in ngram_range:
    pipeline = Pipeline([('CountVectorizer', CountVectorizer(ngram_range=nr)),
                        ('LogisticRegression', LogisticRegression(random_state=2))])
    score = cross_val_score(pipeline, texts, blabels, cv=10, scoring='f1').mean()
    scores1.append(round(score, 2))
    print('F1 score for ngram_range = ' + str(nr) + ': ' + str(round(score, 4)) + '\n')
# Out:
# F1 score for ngram_range = (2, 2): 0.8168
#
# F1 score for ngram_range = (3, 3): 0.725
#
# F1 score for ngram_range = (1, 3): 0.9223

# %%
with open('answer3.txt', 'w') as f:
    f.write(' '.join(map(str, scores1)))

# %% [markdown]
# ## Задание 7.
# Повторите аналогичный п.6 эксперимент, используя вместо логистической регрессии MultinomialNB(). Обратите внимание, насколько сильнее (по сравнению с линейным классификатором) наивный Байес страдает от нехватки статистики по биграммам и триграммам.

# %%
scores2 = []

for nr in ngram_range:
    pipeline = Pipeline([('CountVectorizer', CountVectorizer(ngram_range=nr)),
                         ('multinomial Naive Bayes', MultinomialNB())])
    score = cross_val_score(pipeline, texts, blabels, cv=10, scoring='f1').mean()
    scores2.append(round(score, 2))
    print('F1 score for ngram_range = ' + str(nr) + ': ' + str(round(score, 4)) + '\n')
# Out:
# F1 score for ngram_range = (2, 2): 0.9344
#
# F1 score for ngram_range = (3, 3): 0.8712
#
# F1 score for ngram_range = (1, 3): 0.9472

# %% [markdown]
# По какой-то причине обучение наивного байесовского классификатора через Pipeline происходит с ошибкой. Чтобы получить правильный ответ, отдельно посчитайте частоты слов и обучите классификатор.

# %%
scores3 = []

for nr in ngram_range:
    mx2 = CountVectorizer(ngram_range=nr).fit_transform(texts)
    score = cross_val_score(MultinomialNB(), mx2, blabels, cv=10, scoring='f1').mean()
    scores3.append(round(score, 2))
    print('F1 score for ngram_range = ' + str(nr) + ': ' + str(round(score, 4)) + '\n')
# Out:
# F1 score for ngram_range = (2, 2): 0.6451
#
# F1 score for ngram_range = (3, 3): 0.3786
#
# F1 score for ngram_range = (1, 3): 0.8878

# %%
with open('answer4.txt', 'w') as f:
    f.write(' '.join(map(str, scores3)))

# %% [markdown]
# ## Задание 8.
# Попробуйте использовать в логистической регрессии в качестве признаков Tf*idf из TfidfVectorizer на униграммах. Повысилось или понизилось качество на кросс-валидации по сравнению с CountVectorizer на униграммах? (напишите в файле с ответом 1, если повысилось, -1, если понизилось, и 0, если изменилось не более чем на 0.01). Обратите внимание, что результат перехода к tf*idf не всегда будет таким - если вы наблюдаете какое-то явление на одном датасете, не надо сразу же его обобщать на любые данные.

# %%
pipe2 = Pipeline([('Tfidf vectorizer', TfidfVectorizer()),
                 ('LogisticRegression', LogisticRegression())])

score4 = cross_val_score(pipe2, texts, blabels, cv=10, scoring='f1').mean()
print('F1 score: ' + str(round(score4, 2)))
# Out:
# F1 score: 0.88

# %%
with open('answer5.txt', 'w') as f:
    f.write('-1')
